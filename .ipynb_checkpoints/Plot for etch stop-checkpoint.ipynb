# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
times = ["05", "075", "10", "125", "15"]
stops = np.linspace(10**19, 10**20, 3)

# %%
dfs = []

for i in range(len(times)):
    names = ["depth","doping"]
    df = pd.read_csv(r"C:\Users\Phili\OneDrive\Skrivebord\Skole\DTU\Fysik og Nanoteknologi\22600 Fabrication of micro- and nanostructures\Project\Process Simulation\extract_" + times[i] + "_2e20.dat",
                header=None,
                sep=" ",
                 names = names,
                skiprows=4
                )
    dfs.append(df)

# %%
def func(t, k, t0):
    return np.sqrt(k*(t + t0))

# %%
ts = np.array([0.5, 0.75, 1, 1.25, 1.5]) * 60

# %%
fig, ax = plt.subplots()
filled_marker_style = dict(marker='o', linestyle=':', markersize=15,
                           color='darkgrey',
                           markerfacecolor='tab:blue',
                           markerfacecoloralt='lightsteelblue',
                           markeredgecolor='brown')
new_ts = np.linspace(ts[0], ts[-1], 1000)
for j in range(len(stops)):
    ys = []
    for i in range(len(times)):

        depth = dfs[i].depth.to_numpy()
        doping = dfs[i].doping.to_numpy()
        index = np.argmin(np.abs(np.array(doping)-stops[j]))
        ys.append(depth[index])
    
    popt, pcov = curve_fit(func, ts, ys)
    ans = func(new_ts, popt[0], popt[1])
    ax.scatter(ts, ys, marker="o", edgecolors="r", alpha=0.5)
    ax.plot(new_ts, ans)
    
plt.show()
# Out:
# C:\Users\Phili\AppData\Local\Temp\ipykernel_21628\3006262912.py:2: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(k*(t + t0))

# %%
ts[-1]
# Out:
# 90.0

# %%
ys
# Out:
# [1.06004, 1.83727, 2.59464]

# %%
plt.plot(new_ts, ans)
